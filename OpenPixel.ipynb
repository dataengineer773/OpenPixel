# %%
class Pixel:
    def __init__(self, x=0, y=0, color=None):
        self.x = x
        self.y = y
        self.color = color

class OpenPixel(Pixel):
    pass

# %%
class openPixel(Pixel):
    pass

# %%
op = openPixel()

# %%
op.__dict__
# Out:
# {'x': 0, 'y': 0, 'color': None}

# %%
op.x = 8

# %%
op.__dict__
# Out:
# {'x': 8, 'y': 0, 'color': None}

# %%
op.x
# Out:
# 8

# %%
op.color = 'green'

# %%
op.__dict__
# Out:
# {'x': 8, 'y': 0, 'color': 'green'}
